# %%
import pandas as pd

# %%
games = pd.read_csv("VGSales.csv")

# %%
games.head()
# Out:
#    Rank           Nombre Plataforma    Year     Genre   Publisher  NA_Sales  \
# 0    90          Pac-Man       2600  1982.0    Puzzle       Atari      7.28
# 1   240         Pitfall!       2600  1981.0  Platform  Activision      4.21
# 2   259        Asteroids       2600  1980.0   Shooter       Atari      4.00
# 3   545  Missile Command       2600  1980.0   Shooter       Atari      2.56
# 4   608   Space Invaders       2600     NaN   Shooter       Atari      2.36
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0      0.45       0.0         0.08          7.81
# 1      0.24       0.0         0.05          4.50
# 2      0.26       0.0         0.05          4.31
# 3      0.17       0.0         0.03          2.76
# 4      0.14       0.0         0.03          2.53

# %%
consultarank = games[games["Rank"] >= 16500]
consultarank
# Out:
#         Rank                                             Nombre Plataforma  \
# 639    16515                                      Balloon Pop 2        3DS
# 640    16531                                  Kiniro no Corda 3        3DS
# 641    16538                                       Mushi Bugyou        3DS
# 642    16545  Mario & Luigi: Paper Jam & Mario Kart 7 Double...        3DS
# 643    16570  Fujiko F. Fujio Characters: Great Assembly! Sl...        3DS
# ...      ...                                                ...        ...
# 16593  16533                           Sébastien Loeb Rally Evo       XOne
# 16594  16534                                      Hitman (2016)       XOne
# 16595  16565                                       Mighty No. 9       XOne
# 16596  16572                                 Resident Evil 4 HD       XOne
# 16597  16579                                  Rugby Challenge 3       XOne
#
# ...

# %%
consultapu = games[(games["Publisher"]== "Atari") &
                       (games["Genre"]== "Action")].count()
consultapu
# Out:
# Rank            54
# Nombre          54
# Plataforma      54
# Year            49
# Genre           54
# Publisher       54
# NA_Sales        54
# EU_Sales        54
# JP_Sales        54
# Other_Sales     54
# Global_Sales    54
# dtype: int64

# %%
consultaaño = games[(games["Year"]== "1987.0") &
                       (games["Plataforma"]== "Nes")]
consultaaño
# Out:
# Empty DataFrame
# Columns: [Rank, Nombre, Plataforma, Year, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales]
# Index: []

# %%
consulta_1987_NES = games[(games["Year"] == 1987.0) & (games["Plataforma"] == "NES")]
consulta_1987_NES.count()
# Out:
# Rank            10
# Nombre          10
# Plataforma      10
# Year            10
# Genre           10
# Publisher       10
# NA_Sales        10
# EU_Sales        10
# JP_Sales        10
# Other_Sales     10
# Global_Sales    10
# dtype: int64

# %%
plataformas = ["PS4", "Wii", "X360"]
generos = ["Action", "Fighting", "Puzzle"]

consulta_plataforma_genero = games[(games["Plataforma"].isin(plataformas)) & (games["Genre"].isin(generos))]
consulta_plataforma_genero
# Out:
#         Rank                                  Nombre Plataforma    Year  \
# 10441     45                      Grand Theft Auto V        PS4  2014.0
# 10449    237                          The Last of Us        PS4  2014.0
# 10450    244  Uncharted: The Nathan Drake Collection        PS4  2015.0
# 10452    281                              Watch Dogs        PS4  2014.0
# 10455    305                 Assassin's Creed: Unity        PS4  2014.0
# ...      ...                                     ...        ...     ...
# 15545  16288    Root Double: Before Crime After Days       X360  2012.0
# 15553  16416                The Godfather (JP sales)       X360  2006.0
# 15554  16442            Shin Sangoku Musou 4 Special       X360  2005.0
# 15558  16485                Dragon Ball Z for Kinect       X360  2012.0
# 15559  16536             Metal Gear Solid HD Edition       X360  2011.0
#
#           Genre                     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
AlSuper = pd.read_csv("supermarket_sales.csv")

# %%
AlSuper
# Out:
#        Invoice ID Branch       City Customer type  Gender  \
# 0     253-12-6086      A     Yangon        Member  Female
# 1     276-54-0879      B   Mandalay        Normal    Male
# 2     373-14-0504      A     Yangon        Member  Female
# 3     659-36-1684      C  Naypyitaw        Member    Male
# 4     751-15-6198      B   Mandalay        Normal    Male
# ...           ...    ...        ...           ...     ...
# 1005  811-03-8790      A  Naypyitaw        Normal  Female
# 1006  551-21-3069      C  Naypyitaw        Normal  Female
# 1007  416-17-9926      A  Naypyitaw        Member  Female
# 1008  556-97-7101      C  Naypyitaw        Normal  Female
# 1009  891-01-7034      B  Naypyitaw        Normal  Female
#
#                 Product line  Unit price  Quantity   Tax 5%     Total  Rating  \
# 0          Sports and travel       98.40         7  34.4400   $723.24     8.7
# 1          Sports and travel       97.74         4  19.5480   $410.51     6.4
# ...

# %%
consulta = AlSuper[(AlSuper["City"] == "Yangon") & 
                   (AlSuper["Gender"] == "Male") & 
                   (AlSuper["Product line"] == "Sports and travel") & 
                   (AlSuper["Payment"] == "Credit card")].count()
consulta
# Out:
# Invoice ID                 9
# Branch                     9
# City                       9
# Customer type              9
# Gender                     9
# Product line               9
# Unit price                 9
# Quantity                   9
# Tax 5%                     9
# Total                      9
# Rating                     9
# Payment                    9
# Date                       9
# Time                       9
# cogs                       9
# gross margin percentage    9
# gross income               9
# dtype: int64

# %%
consulta
# Out:
#       Invoice ID Branch    City Customer type Gender       Product line  \
# 8    289-15-7034      A  Yangon        Member   Male  Sports and travel
# 34   541-48-8554      A  Yangon        Normal   Male  Sports and travel
# 36   199-75-8169      A  Yangon        Member   Male  Sports and travel
# 57   550-84-8664      A  Yangon        Normal   Male  Sports and travel
# 64   828-61-5674      A  Yangon        Member   Male  Sports and travel
# 142  149-61-1929      A  Yangon        Normal   Male  Sports and travel
# 145  882-40-4577      A  Yangon        Member   Male  Sports and travel
# 161  105-31-1824      A  Yangon        Member   Male  Sports and travel
# 165  765-26-6951      A  Yangon        Normal   Male  Sports and travel
#
#      Unit price  Quantity   Tax 5%    Total  Rating      Payment        Date  \
# 8         82.33         4  16.4660  $345.79     7.5  Credit card  01/11/2019
# 34        60.95         9  27.4275  $575.98     6.0  Credit card  01/07/2019
# ...

# %%
consultati = AlSuper[(AlSuper["City"] == "Naypyitaw") & 
                   (AlSuper["Customer type"] == "Member") & 
                   ((AlSuper["Payment"] == "Cash") | (AlSuper["Payment"] == "Ewallet"))]
consultati
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 18   360-39-5055      C  Naypyitaw        Member    Male
# 32   784-21-9238      C  Naypyitaw        Member    Male
# 33   232-16-2483      C  Naypyitaw        Member  Female
# 54   835-16-0096      C  Naypyitaw        Member    Male
# 61   102-06-2002      C  Naypyitaw        Member    Male
# ..           ...    ...        ...           ...     ...
# 936  652-49-6720      C  Naypyitaw        Member  Female
# 941  273-84-2164      C  Naypyitaw        Member    Male
# 942  233-34-0817      C  Naypyitaw        Member  Female
# 960  583-72-1480      C  Naypyitaw        Member    Male
# 970  325-90-8763      C  Naypyitaw        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%    Total  Rating  \
# 18        Sports and travel       48.91         5  12.2275  $256.78     6.6
# 32        Sports and travel       10.17         1   0.5085   $10.68     5.9
# ...
